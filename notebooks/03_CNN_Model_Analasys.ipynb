# %%
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

from src.cnn_analysis2 import ModelAnalyzer  # <- lub cnn_analysis2

# Ścieżki do plików
MODEL_PATH = '../notebooks/models/cnn/best_model.pth'
DATA_PATH = '../notebooks/data/processed/cleaned_data.csv'

print("🔧 Inicjalizacja analizatora...")
analyzer = ModelAnalyzer(MODEL_PATH, DATA_PATH)
print("✅ Gotowe!")

analyzer.plot_training_history()
analyzer.plot_predictions_comparison()
analyzer.plot_error_analysis()
analyzer.plot_metrics_summary()
analyzer.plot_future_predictions(days=30)
analyzer.plot_future_predictions(days=7)

# Cały dashboard
analyzer.create_dashboard()
# Out:
# 🔧 Inicjalizacja analizatora...
# ✅ Model i predykcje załadowane z pliku
# ✅ Gotowe!
# 📊 Podsumowanie predykcji na 30 dni:
#    💰 Aktualna cena: $599.14
#    🎯 Przewidywana cena: $548.82 (±$87.81)
#    📈 Oczekiwana zmiana: -8.4%
# 📊 Podsumowanie predykcji na 7 dni:
#    💰 Aktualna cena: $599.14
#    🎯 Przewidywana cena: $648.15 (±$103.70)
#    📈 Oczekiwana zmiana: +8.2%
# 🎨 Generowanie Dashboard CNN...
# ...
# 📊 Podsumowanie predykcji na 30 dni:
#    💰 Aktualna cena: $599.14
#    🎯 Przewidywana cena: $548.82 (±$87.81)
#    📈 Oczekiwana zmiana: -8.4%
# ✅ Dashboard wygenerowany!
