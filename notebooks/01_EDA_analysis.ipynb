# %% [markdown]
# # Eksploracyjna Analiza Danych (EDA) - Dane Giełdowe

# %% [markdown]
# ## 1. Import bibliotek i wczytanie danych

# %%
import sys
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Dodaj ścieżkę do modułu
sys.path.append('..')

# Import klasy EDA
from src.eda import StockEDA

# Ścieżka do danych
data_path = r"C:\Users\pawli\OneDrive\Pulpit\sieci\Projektowanie_i_zastosowania_sieci_neuronowych\data\data\processed\cleaned_data.csv"

# Wczytaj dane
df = pd.read_csv(data_path)
print(f"✅ Wczytano {len(df)} rekordów")
print(f"📊 Kolumny: {list(df.columns)}")
# Out:
# ✅ Wczytano 2623 rekordów
# 📊 Kolumny: ['Date', 'Open', 'High', 'Low', 'Close/Last', 'Volume']

# %% [markdown]
# ## 2. Uruchomienie analizy EDA

# %%
# Utwórz obiekt EDA
eda = StockEDA(df, date_col='Date', price_col='Close/Last')

# Uruchom pełną analizę - wszystkie wykresy i statystyki
eda.plot_all_analysis()
# Out:
# 📊 STATYSTYKI CENOWE:
# Cena min: $156.33
# Cena max: $611.09
# Cena średnia: $323.72
# Zakres dat: 2015-01-02 - 2025-06-06
# 📈 STATYSTYKI ZWROTÓW:
# Średni zwrot dzienny: 0.0541%
# Średni zwrot roczny: 13.63%
# Zmienność dzienna: 1.1401%
# Zmienność roczna: 18.10%
# Sharpe Ratio: 0.75
# Skośność: -0.30
# Kurtoza: 13.88
# ...
# 📊 PODSUMOWANIE ANALIZY EDA
# ...
#
# 🗓️ DANE:
# Liczba obserwacji: 2623
# Zakres dat: 2015-01-02 - 2025-06-06
# Liczba dni: 3807
#
# 💰 CENY:
# Min: $156.33
# Max: $611.09
# Średnia: $323.72
# Obecna: $599.14
#
# 📈 ZWROTY:
# Średni dzienny: 0.0541%
# Średni roczny: 13.63%
# Zmienność roczna: 18.10%
# Sharpe Ratio: 0.75
#
# 🎯 EKSTREMALNE WARTOŚCI:
# Największy wzrost: 10.50% (2025-04-09)
# Największy spadek: -10.94% (2020-03-16)
#
# ...
