# %% [markdown]
# # Eksploracyjna Analiza Danych (EDA) - Dane Giełdowe

# %% [markdown]
# ## 1. Import bibliotek i wczytanie danych

# %%
import sys
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Dodaj ścieżkę do modułu
sys.path.append('..')

# Import klasy EDA
from src.eda import StockEDA

# Ścieżka do danych
data_path = r"C:\Users\pawli\OneDrive\Pulpit\sieci\Projektowanie_i_zastosowania_sieci_neuronowych\apple_stock_data.csv"

# Wczytaj dane
df = pd.read_csv(data_path)
print(f"✅ Wczytano {len(df)} rekordów")
print(f"📊 Kolumny: {list(df.columns)}")
# Out:
# ✅ Wczytano 750 rekordów
# 📊 Kolumny: ['Date', 'Open', 'High', 'Low', 'Close/Last', 'Volume']

# %%
print(df.head())
# Out:
#                        Date        Open        High         Low  Close/Last  \
# 0  2022-06-21 00:00:00-0400  131.313313  134.895837  131.214901  133.724625
# 1  2022-06-22 00:00:00-0400  132.661675  135.584780  131.795580  133.212845
# 2  2022-06-23 00:00:00-0400  134.659644  136.401686  133.488432  136.086746
# 3  2022-06-24 00:00:00-0400  137.690968  139.669240  137.563031  139.423187
# 4  2022-06-27 00:00:00-0400  140.446759  141.224293  138.744080  139.423187
#
#      Volume
# 0  81000500
# 1  73409200
# 2  72433800
# 3  89116800
# 4  70207900

# %% [markdown]
# ## 2. Uruchomienie analizy EDA

# %%
# Utwórz obiekt EDA
eda = StockEDA(df, date_col='Date', price_col='Close/Last')

# Uruchom pełną analizę - wszystkie wykresy i statystyki
eda.plot_all_analysis()
# Out:
# 📊 STATYSTYKI CENOWE:
# Cena min: $123.42
# Cena max: $258.40
# Cena średnia: $185.53
# Zakres dat: 2022-06-21 - 2025-06-16
# 📈 STATYSTYKI ZWROTÓW:
# Średni zwrot dzienny: 0.0685%
# Średni zwrot roczny: 17.26%
# Zmienność dzienna: 1.7849%
# Zmienność roczna: 28.33%
# Sharpe Ratio: 0.61
# Skośność: 0.73
# Kurtoza: 9.73
# ============================================================
# 📊 PODSUMOWANIE ANALIZY EDA
# ============================================================
#
# 🗓️ DANE:
# Liczba obserwacji: 750
# Zakres dat: 2022-06-21 - 2025-06-16
# Liczba dni: 1091
#
# 💰 CENY:
# Min: $123.42
# Max: $258.40
# Średnia: $185.53
# Obecna: $198.42
#
# 📈 ZWROTY:
# Średni dzienny: 0.0685%
# Średni roczny: 17.26%
# Zmienność roczna: 28.33%
# Sharpe Ratio: 0.61
#
# 🎯 EKSTREMALNE WARTOŚCI:
# Największy wzrost: 15.33% (2025-04-09)
# Największy spadek: -9.25% (2025-04-03)
#
# ============================================================
#                        Date        Open        High         Low  Close/Last  \
# 0  2022-06-21 00:00:00-0400  131.313313  134.895837  131.214901  133.724625
# 1  2022-06-22 00:00:00-0400  132.661675  135.584780  131.795580  133.212845
# 2  2022-06-23 00:00:00-0400  134.659644  136.401686  133.488432  136.086746
# 3  2022-06-24 00:00:00-0400  137.690968  139.669240  137.563031  139.423187
# 4  2022-06-27 00:00:00-0400  140.446759  141.224293  138.744080  139.423187
#
#      Volume
# 0  81000500
# 1  73409200
# 2  72433800
# 3  89116800
# 4  70207900
