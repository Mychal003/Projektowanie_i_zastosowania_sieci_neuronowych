# %% [markdown]
# # Notebook do analizy eksploracyjnej

# %% [markdown]
# ## Importy

# %%
import sys
import importlib
import eda
sys.path.append("../src")

from data_preprocessing import preprocess
from eda import (
    plot_summary,
    plot_price_interpolation,
    plot_price_distribution,
    plot_price_distribution,
    show_basic_statistics,
    plot_close_distribution,
    plot_trend_line,
    plot_daily_returns,
    plot_monthly_boxplot,
    plot_correlation_matrix
)

df = preprocess()

#ponowne załadowanie modułu
import importlib
importlib.reload(eda)
# Out:
# <module 'eda' from '../src\\eda.py'>

# %% [markdown]
# ## Wyświetlenie przykładowych danych

# %%
print("Przykładowe dane:")
print(df.head())
# Out:
# Przykładowe dane:
#         Date  Close/Last     Volume    Open    High     Low
# 0 2024-04-05      164.90  143157600  169.08  170.86  160.51
# 1 2024-04-08      172.98  104423300  169.34  174.50  167.79
# 2 2024-04-09      176.88  103232700  172.91  179.22  171.92
# 3 2024-04-10      171.76   84532410  173.04  174.93  170.01
# 4 2024-04-11      174.60   94515990  172.55  175.88  168.51

# %% [markdown]
# ## Przedstawienie zmienności cen zamknięcia w czasie

# %%
plot_trend_line(df)

# %% [markdown]
# ## interpolacja

# %%
plot_price_interpolation(df)

# %% [markdown]
# ## Dystrybucja cen zamknięcia USD

# %%
plot_price_distribution(df)

# %%
show_basic_statistics(df)
# Out:
# Statystyki opisowe:
#                                  Date  Close/Last        Volume        Open  \
# count                            251  251.000000  2.510000e+02  251.000000
# mean   2024-10-04 00:11:28.446215168  265.217131  9.452998e+07  265.488629
# min              2024-04-05 00:00:00  142.050000  3.716762e+07  140.560000
# 25%              2024-07-06 12:00:00  199.440000  6.747026e+07  199.285000
# 50%              2024-10-03 00:00:00  242.840000  8.453241e+07  244.560000
# 75%              2025-01-02 12:00:00  334.700000  1.119144e+08  339.435000
# max              2025-04-04 00:00:00  479.860000  2.438697e+08  475.900000
# std                              NaN   83.557966  3.700690e+07   84.020752
#
#              High         Low  DateNumeric
# count  251.000000  251.000000   251.000000
# mean   271.694890  258.759067   182.007968
# min    144.440000  138.802500     0.000000
# 25%    203.345000  194.890000    92.500000
# 50%    249.790000  237.810000   181.000000
# 75%    346.120000  327.855000   272.500000
# max    488.539900  457.510100   364.000000
# std     86.137943   80.963177   105.996943
#
# Braki danych:
#  Date           0
# Close/Last     0
# Volume         0
# Open           0
# High           0
# Low            0
# DateNumeric    0
# dtype: int64

# %% [markdown]
# ## Rozkład dziennej stopy zwrotu

# %%
plot_daily_returns(df)

# %% [markdown]
# ## Rozkład cen według miesiąca

# %%
plot_monthly_boxplot(df)

# %% [markdown]
# ## Macierz korelacji

# %%
plot_correlation_matrix(df)
